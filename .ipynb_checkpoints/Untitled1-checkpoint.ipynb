# %%
import matplotlib.pyplot as plt
plt.plot([1,5,10,50,125,250,500,750,1000],[14.024000,4.058000,2.778000,2.081000,1.848000,1.915000,1.873000,1.900000,1.928000],label= "RGB to YUV")
plt.plot([1,5,10,50,125,250,500,750,1000],[9.151000,2.894000,2.108000,1.659000,1.531000,1.561000,1.524000,1.650000,1.598000],label= "YUV to RGB")
plt.plot([1,5,10,50,125,250,500,750,1000],[0.231000,0.248000,0.224000,0.237000,0.266000,0.236000,0.246000,0.216000,0.239000],label= "Copy from Host to Device")
plt.plot([1,5,10,50,125,250,500,750,1000],[0.402000,0.402000,0.386000,0.416000,0.394000,0.405000,0.420000,0.385000,0.409000],label= "Copy from Device to Host")
plt.ylabel('Time(ms)')
plt.xlabel('No. of Threads')
leg = plt.legend(loc='best', ncol=1, shadow=True, fancybox=True)
leg.get_frame().set_alpha(0.5)
plt.show()

# %%
plt.plot([1,5,10,50,125,250,500,750,1000],[21.177000,21.388000,20.868999,20.864000,20.778999,21.129999,21.503000,21.080999,20.808001],label= "Copy from Host to Device")
plt.plot([1,5,10,50,125,250,500,750,1000],[39.418999,40.409000,39.459000,39.752998,39.849998,39.381001,39.201000,39.055000,40.252998],label= "Copy from Device to Host")
plt.plot([1,5,10,50,125,250,500,750,1000],[1080.706055,315.239014,194.145996,123.000999,111.392998,111.712997,112.042000,112.153999,123.185997],label= "RGB to YUV")
plt.plot([1,5,10,50,125,250,500,750,1000],[626.408997,190.186005,135.660004,97.945000,96.000000,96.296997,96.200996,97.842003,93.500000],label= "YUV to RGB")
plt.ylabel('Time(ms)')
plt.xlabel('No. of Threads')
leg = plt.legend(loc='best', ncol=1, shadow=True, fancybox=True)
leg.get_frame().set_alpha(0.5)
#plt.xlim(-1,1000)
plt.show()
